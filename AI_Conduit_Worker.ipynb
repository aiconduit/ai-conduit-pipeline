# %% [markdown]
# # 🤖 AI Conduit 自動ワーカー
# GitHubトレンド収集 → DeepSeekでコンテンツ生成 → 動画作成 → YouTubeアップロード

# %%
# Step1: セットアップ
# !apt-get install -y ffmpeg fonts-noto-cjk fonts-noto-cjk-extra -q
# !pip install requests pillow numpy google-auth google-auth-oauthlib google-api-python-client -q
# !git clone https://github.com/aiconduit/ai-conduit-pipeline.git
# %cd ai-conduit-pipeline
print('✅ セットアップ完了')

# %%
# Step2: APIキー設定
import os
os.environ['DEEPSEEK_KEY'] = 'sk-71eab12699f047a5891e62268c66c241'
os.environ['GROQ_API_KEY'] = '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'
os.environ['GOOGLE_TTS_KEY'] = 'AIzaSyCsrOd3cgi9hcnoOeFXRde9prLAy6Y2vdY'
os.environ['PEXELS_API_KEY'] = 'LSsE8rcX23VNaFN0M0F19PCMtoLhEyg1NxZpIqwr7aCuvUYInctIexrW'
print('✅ APIキー設定完了')

# %%
# Step3: GitHubトレンド収集
# !python3 sns_automation/scripts/trending_collector.py

# %%
# Step4: コンテンツ計画生成
# !python3 sns_automation/scripts/content_planner.py

# %%
# Step5: 動画生成
# !python3 run_from_content_plan.py

# %%
# Step6: 動画ダウンロード
from google.colab import files
import glob
videos = glob.glob('projects/daily/renders/*.mp4')
print(f'生成動画: {len(videos)}本')
for v in sorted(videos)[-3:]:
    print(f'ダウンロード: {v}')
    files.download(v)
